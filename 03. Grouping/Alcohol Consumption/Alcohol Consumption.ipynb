# %%
#Step 1. Import the necessary libraries
import pandas as pd

# %%
#Step 2. Import the dataset from this address.
#Step 3. Assign it to a variable called drinks.

drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
#Step 4. Which continent drinks more beer on average?
beer_mean = drinks.beer_servings.mean()
beer_mean
drinks.loc[drinks.beer_servings > beer_mean]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 3           Andorra            245              138            312
# 4            Angola            217               57             45
# 6         Argentina            193               25            221
# 8         Australia            261               72            212
# 9           Austria            279               75            191
# ..              ...            ...              ...            ...
# 182  United Kingdom            219              126            195
# 184             USA            249              158             84
# 185         Uruguay            115               35            220
# 188       Venezuela            333              100              3
# 189         Vietnam            111                2              1
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 4                             5.9        AF
# ...

# %%
#Step 5. For each continent print the statistics for wine consumption
drinks.iloc[:,[3,5]].groupby('continent').sum()
# Out:
#            wine_servings
# continent
# AF                   862
# AS                   399
# EU                  6400
# OC                   570
# SA                   749

# %%
#Step 6. Print the mean alcohol consumption per continent for every column
continent_alcohol = drinks.iloc[:,[4,5]].groupby('continent').mean()
continent_alcohol.columns =  ['alcohol_mean']
drinks = pd.merge(drinks, continent_alcohol, left_on='continent', right_on='continent', how = 'left')
drinks

#another answer
drinks.groupby('continent').mean()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  alcohol_mean
# 0                             0.0        AS      2.170455
# 1                             4.9        EU      8.617778
# ...

# %%
#Step 7. Print the median alcohol consumption per continent for every column
continent_alcohol = drinks.iloc[:,[4,5]].groupby('continent').median()
continent_alcohol.columns =  ['alcohol_median']
drinks = pd.merge(drinks, continent_alcohol, left_on='continent', right_on='continent', how = 'left')
drinks

#drinks.groupby('continent').median()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  alcohol_mean  alcohol_median
# 0                             0.0        AS      2.170455            1.20
# ...

# %%
#Step 8. Print the mean, min and max values for spirit consumption.
#This time output a DataFrame
# drinks.alcohol_median.mean()
# drinks.alcohol_median.min()
# drinks.alcohol_median.max()

drinks['alcohol_median'].agg(['max','min','mean'])

#Answer
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
# max     10.000000
# min      1.200000
# mean     4.322941
# Name: alcohol_median, dtype: float64
