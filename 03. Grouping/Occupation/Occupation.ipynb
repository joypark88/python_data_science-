# %%
#Step 1. Import the necessary libraries
import pandas as pd

# %%
#Step 2. Import the dataset from this address.¶
#Step 3. Assign it to a variable called users.

users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
#Step 4. Discover what is the mean age per occupation
users.groupby('occupation').age.mean().round()
# Out:
# occupation
# administrator    39.0
# artist           31.0
# doctor           44.0
# educator         42.0
# engineer         36.0
# entertainment    29.0
# executive        39.0
# healthcare       42.0
# homemaker        33.0
# lawyer           37.0
# librarian        40.0
# marketing        38.0
# none             27.0
# other            35.0
# programmer       33.0
# retired          63.0
# salesman         36.0
# scientist        36.0
# student          22.0
# technician       33.0
# writer           36.0
# Name: age, dtype: float64

# %%
#Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# Wrong! (Hard)

gender_total= users.groupby(['occupation']).count()
gender_total

gender_split =  users.groupby(['gender', 'occupation']).count()
male = gender_split[20:]

male_ratio = male/gender_total * 100

male_ratio.sort_values(by = 'age', ascending = False)

#sum이 아니라!! count!! 



#another way

# create a function
# def gender_to_numeric(x):
#     if x == 'M':
#         return 1
#     if x == 'F':
#         return 0

# # apply the function to the gender column and create a new column
# users['gender_n'] = users['gender'].apply(gender_to_numeric)


# a = users.groupby('occupation').gender_n.sum() / users.occupation.value_counts() * 100 

# # sort to the most male 
# a.sort_values(ascending = False)
# Out:
#                              age  gender    zip_code
# gender occupation
# M      doctor         100.000000     NaN  100.000000
#        engineer        97.014925     NaN   97.014925
#        technician      96.296296     NaN   96.296296
#        retired         92.857143     NaN   92.857143
#        programmer      90.909091     NaN   90.909091
#        executive       90.625000     NaN   90.625000
#        scientist       90.322581     NaN   90.322581
#        entertainment   88.888889     NaN   88.888889
#        lawyer          83.333333     NaN   83.333333
#        salesman        75.000000     NaN   75.000000
#        educator        72.631579     NaN   72.631579
#        student         69.387755     NaN   69.387755
#        other           65.714286     NaN   65.714286
#        marketing       61.538462     NaN   61.538462
#        writer          57.777778     NaN   57.777778
#        none            55.555556     NaN   55.555556
# ...

# %%
#Step 6. For each occupation, calculate the minimum and maximum ages
users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#Step 7. For each combination of occupation and gender, calculate the mean age
users.groupby(['occupation','gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
#Step 8. For each occupation present the percentage of women and men
# Wrong! (Hard)
total = users.groupby(['occupation']).age.count()
gender = users.groupby(['occupation','gender']).age.count()

gender.div(total, level = 'occupation') * 100  #div사용해서 나누기!!!!!!!
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...
